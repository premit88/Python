# %% [markdown]
# ## 1) Basic Data Types
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### Example 1

# %%
print(10_0 + 5_0)       # Better for readibility
print(1)
print(10.0)
print(True)
print(0.1)              # SOME repleating float does not have exact reprentation. Python is just making them pretty. 
format(0.1 , '.25f')    # Let's see the actual 25 digits after 0.1. # NOTE : This is why don't compare floats.
# Out:
# 150
# 1
# 10.0
# True
# 0.1
# '0.1000000000000000055511151'

# %% [markdown]
# ### Example 2

# %%
1 + 1 + 1 == 3      # Comparing left side with rigt side # NOTE we are using  double equals
# Out:
# True

# %% [markdown]
# ### Example 3

# %%
0.125 + 0.125 + 0.125 == 0.375      # Float is giving TRUE because exact representation is possible.
# Out:
# True

# %% [markdown]
# ### Example 4

# %%
print(0.1 + 0.1 + 0.1 == 0.3)          # NOTE : Exact representation of float 0.1 is not possible, that is why FALSE

print (format (0.1 + 0.1 + 0.1, '.25f'))

print(format(0.3, '.25f'))

print('''Both values are close to each other but not same, 
      Bottom Line : Dont use equality for comapring floats''')
# Out:
# False
# 0.3000000000000000444089210
# 0.2999999999999999888977698
# Both values are close to each other but not same,
#       Bottom Line : Dont use equality for comapring floats

# %% [markdown]
# ### Example 5
#
# One way to overcome the problem of float comparision is by finding difference between their absolute values and fixing a tolerance value for acceptance.

# %%
abs((0.1 + 0.1 + 0.1) - 0.3) < 0.001
# Out:
# True

# %%
print('hello github')
# Out:
# hello github
