# %% [markdown]
# ## 5) Operator Precedence
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ### The table shows precedence from highest to lowest
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### Example 1

# %%
10 * 4 + 5 * 5
# Out:
# 65

# %% [markdown]
# ### Example 2

# %%
10 * (2**3) + 5
# Out:
# 85

# %% [markdown]
# ### Example 3

# %%
2 ** -3
# Out:
# 0.125

# %%
-2 ** 3
# Out:
# -8

# %% [markdown]
# ### Example 4

# %%
-4 ** 0.5       # NOTE : Don't confuse this with taking the square root of a negative number. This is different.
# Out:
# -2.0

# %%
(-4) ** 0.5      # As expexted, square root of a negative number is a complex number.
# Out:
# (1.2246467991473532e-16+2j)
