# %% [markdown]
# ## 3) Strings
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
a = 'Hello'
b = "Python"
c = "O'Neil"
print(a , b, c)
# Out:
# Hello Python O'Neil

# %%
d = 'Python's best features:
print(d)
# Out:
#   Cell In[5], line 1
#     d = 'Python's best features:
#                 ^
# SyntaxError: invalid syntax

# %%
e = 'Pyhon\'s best features:'
print(e)
# Out:
# Pyhon's best features:

# %%
f = 'Python rocks!'
print(f[0])
print(f[1])
print(len(f))
# Out:
# P
# y
# 13
